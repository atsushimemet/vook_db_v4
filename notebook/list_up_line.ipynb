# %% [markdown]
# # Import

# %%
import re
import sys
from pathlib import Path

import pandas as pd

# %% [markdown]
# # Global

# %%
OUTPUT_PATH = Path("../data/output/")
file_name = "20230501_214137_for_issue_35.csv"

# %% [markdown]
# # Main

# %%
item_names = pd.read_csv(OUTPUT_PATH / file_name)["itemDesc"]

# %%
item_names.tolist()[2]
# Out:
# "■商品情報<br>[商品番号]3023C190015<br>[ブランド]Levi's（リーバイス）<br>[モデル]40s VINTAGE 501XX 革パッチ 片面タブ デニムパンツ ヴィンテージ インディゴ<br>[サイズ]ウエスト：51センチ ワタリ：36センチ 股上：37.5センチ 股下：68.5センチ 裾幅：23センチ<br>表記サイズ：‐<br>■状態・コンディション<br>[状態ランク]<br>ランク B<br>使用感有り<br>前身頃右/両裾口に汚れ有り<br>後身頃上部にほつれ有り<br>[備考]-<br>[販売店舗]AWESOME原宿店"

# %%
item_names.tolist()[:30]
# Out:
# ["■商品情報<br>[商品番号]3523D220011<br>[ブランド]Levi's（リーバイス）<br>[モデル]50s VINTAGE 506XX 1st DENIM JACKET BIG E スライドバックル 1950年代前半 デニムジャケット ビッグE 革パッチ ヴィンテージ インディゴ<br>[サイズ]着丈：56.5センチ 身幅：54.8センチ 肩幅：46.0センチ 袖丈：58.0センチ<br>表記サイズ：‐<br>■状態・コンディション<br>[状態ランク]<br>ランク C<br>使用感有り<br>ヴィンテージ特有の使用感有り<br>首元パッチ欠損有り<br>各ボタン部分/後身頃金具部分変色/小傷有り<br>全体的に汚れ有り<br>[備考]左右袖口/裾周り擦れ有り , 右袖口付近お直し有り<br>[販売店舗]AWESOME原宿店",
#  "品番：lvs-pstr-50<br>生地：巻き段ボール紙<br><br>サイズ/縦/横/マチ/<br>F/約87/約231.5/約2/<br><br>【当店はLevi's(リーバイス)の取扱店です】",
#  "■商品情報<br>[商品番号]3023C190015<br>[ブランド]Levi's（リーバイス）<br>[モデル]40s VINTAGE 501XX 革パッチ 片面タブ デニムパンツ ヴィンテージ インディゴ<br>[サイズ]ウエスト：51センチ ワタリ：36センチ 股上：37.5センチ 股下：68.5センチ 裾幅：23センチ<br>表記サイズ：‐<br>■状態・コンディション<br>[状態ランク]<br>ランク B<br>使用感有り<br>前身頃右/両裾口に汚れ有り<br>後身頃上部にほつれ有り<br>[備考]-<br>[販売店舗]AWESOME原宿店",
# ...
